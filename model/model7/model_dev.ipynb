# %%
import gc
from itertools import combinations
import os
import sys
import time
from typing import Optional
from unicodedata import bidirectional
from imblearn.over_sampling import SMOTE
import joblib
from keras._tf_keras.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard
from keras._tf_keras.keras.metrics import MeanAbsoluteError, Accuracy, Precision, Recall, MeanSquaredError
from keras._tf_keras.keras.models import Sequential
from keras._tf_keras.keras.optimizers import Adam , RMSprop, Nadam
from keras._tf_keras.keras.preprocessing.sequence import pad_sequences 
from keras._tf_keras.keras.layers import LSTM, Dense, Dropout, Bidirectional, BatchNormalization, Masking, InputLayer
from keras._tf_keras.keras.regularizers import L1L2, L1, L2
from keras._tf_keras.keras.utils import to_categorical
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import scipy
from scipy.sparse import csr_matrix
from scipy.stats import skew, kurtosis
import seaborn as sns
from sklearn.calibration import LabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.experimental import enable_iterative_imputer
from sklearn.feature_selection import SelectFromModel
from sklearn.impute import IterativeImputer, KNNImputer, SimpleImputer
from sklearn.linear_model import Lasso
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import TimeSeriesSplit
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder

from FeatureEngineering import FeatureEngineering as fe

# %%
def create_dataframe_from_data(input_path: str):
    dataframes = []

    for file_name in os.listdir(input_path):
        if file_name.endswith(".npy"):
            file_path = os.path.join(input_path, file_name)

            data = np.load(file_path, allow_pickle=True)
            df = pd.DataFrame(data)

            gesture = file_name.split("_")[0]
            gesture_index = int(file_name.split("_")[1].split(".")[0])
            df["gesture"] = gesture
            df["gesture_index"] = gesture_index

            dataframes.append(df)
            df.sort_values(by="frame", inplace=True)
    
    return pd.concat(dataframes, ignore_index=True) if len(dataframes) > 0 else ValueError("Dataframe has no data")



def split_dataset(dataframe: pd.DataFrame, target_label: str, additional_targets: list=None, train_ratio=0.8, test_ratio=0.2):
    
    assert train_ratio  + test_ratio == 1.0, "Ratios must sum to 1."
    
    train_frames = []
    test_frames = []

    for _, gesture_data in dataframe.groupby("gesture_index"):
        n_frames = len(gesture_data)
        n_train = int(n_frames * train_ratio)

        train_split = gesture_data.iloc[:n_train]
        test_split = gesture_data.iloc[n_train:]

        train_frames.append(train_split)
        test_frames.append(test_split)
    
    train_set = pd.concat(train_frames).reset_index(drop=True)
    test_set = pd.concat(test_frames).reset_index(drop=True)

    # Separate X and y
    X_train = train_set.drop(columns=[target_label])
    y_train = train_set[[target_label] + additional_targets]
    X_test = test_set.drop(columns=[target_label])
    y_test = test_set[[target_label] + additional_targets]

    return X_train, y_train, X_test, y_test

# %%
def calculate_hand_motion_features(df: pd.DataFrame, landmark_cols: list):
        
        df_copy = df.copy()

        # s = time.process_time()
        df_elapsed = fe.calculate_elapsed_time(df_copy)    
        df_temporal = fe.calculate_temporal_features(df_copy, landmark_cols)
        # df_stats = fe.calculate_temporal_stats(df_copy, landmark_cols)
        # df_pairwise = fe.calculate_landmark_distances(df_copy, landmark_cols)
        df_angle = fe.calculate_landmark_angles(df_copy, landmark_cols)
        df_combined = pd.concat([df_copy, df_angle], axis=1)
        # print(time.process_time()-s)
        
        # Ensure there are no duplicate columns
        df_combined = df_combined.loc[:,~df_combined.columns.duplicated()]
        return df_combined

# %%
def preprocess_pipeline(timeseries_columns, numerical_columns, categorical_columns):
    ts_numerical_transformer = Pipeline(steps=[
        ('imputer', KNNImputer(n_neighbors=5)), # might want to change this out back to the interpolatioon methods
        ('imputer2', SimpleImputer(strategy="mean")),
        ('scaler', MinMaxScaler())
    ])

    numerical_transformer = Pipeline(steps=[
        ('imputer', SimpleImputer(strategy="mean")),
        ("normalize", StandardScaler())
    ])

    categorical_transformer = Pipeline(steps=[
        ('imputer', SimpleImputer(strategy="most_frequent")), # technically this is wrong
        ("ohe", OneHotEncoder(sparse_output=False))
    ])

    preprocessor = ColumnTransformer(
        transformers=[
            ('ts_num', ts_numerical_transformer, timeseries_columns),
            ('num', numerical_transformer, numerical_columns),
            ('cat', categorical_transformer, categorical_columns)
        ],
        remainder='passthrough',
        sparse_threshold=0,
        n_jobs=-1
    )
 
    preprocessor.set_output(transform="pandas")
    
    return preprocessor

# %%
def reshape_y_labels(df: pd.DataFrame):
    """
    reasoning for this function:
    a single gesture recording can have the same index of n frames.
    This will balloon the size of the (x, y), when in reality it's much
    smaller. This will goo through each frame, and if the continuous pattern
    breaks (e.g. 12 -> 0), everything before "12" will be removed keeping only
    one instance of the gesture
    """
    unique_sequences = []
    for _, group in df.groupby("gesture_index"):
        reset_points = group['frame'].diff().fillna(1) < 0
        if reset_points.any():
            unique_sequences.append(group[reset_points])
        else:
            # If no reset points, consider the whole group as unique
            unique_sequences.append(group.iloc[[0]])

    # Concatenate unique sequences
    df_unique = pd.concat(unique_sequences).reset_index(drop=True)
    return df_unique["gesture"]

def encode_labels(y_train_reshaped, y_test_reshaped):
    label_encoder = LabelEncoder()
    combined_labels = pd.concat([y_train_reshaped, y_test_reshaped])
    label_encoder.fit_transform(combined_labels)

    y_train_encoded = label_encoder.fit_transform(y_train_reshaped)
    y_test_encoded = label_encoder.fit_transform(y_test_reshaped)

    return label_encoder,y_train_encoded, y_test_encoded

def find_longest_continuous_chain(df: pd.DataFrame):
    gesture_index_cols = df.columns[df.columns.str.startswith("cat__gesture_index_")]

    longest_length = 0 
    target_gesture_index = None 

    for col in gesture_index_cols:
        gesture_index = col.split("_")[-1]
        gesture_data = df[col].values 

        # Use NumPy to find the lengths of continuous sequences of 1s
        padded = np.pad(gesture_data, (1, 1), constant_values=0)
        diff = np.diff(padded)
        start_indices = np.where(diff == 1)[0]
        end_indices = np.where(diff == -1)[0]
        lengths = end_indices - start_indices
        
        max_length = lengths.max() if lengths.size > 0 else 0

        if max_length > longest_length:
            longest_length = max_length
            target_gesture_index = gesture_index

    return [longest_length, target_gesture_index]

def pad_dataframe(df: pd.DataFrame, train_pad_len = None):

    frame_list = find_longest_continuous_chain(df.copy())

    cols_to_pad = [col for col in df.columns if col.startswith("cat__gesture_index_") and col != frame_list[1]]
    num_of_cols = [col for col in df.columns if col.startswith("cat__gesture_index_")]

    if train_pad_len is not None:
        frame_list[0] = train_pad_len 
        cols_to_pad = [col for col in df.columns if col.startswith("cat__gesture_index_")]
        num_of_cols = [col for col in df.columns if col.startswith("cat__gesture_index_")]

    columns = df.columns
    data = df.values 
    for col in cols_to_pad:
        col_index = df.columns.get_loc(col)
        num_frames = int(df[col].sum())
        frames_diff = frame_list[0] - num_frames

        if frames_diff > 0: 
            gesture_index_rows = np.where(data[:, col_index] == 1)[0]
            last_frame_index = gesture_index_rows[-1]
            
            # Create padding array with -1 values for all columns except the current col
            padding_data = np.full((frames_diff, data.shape[1]), -1)
            padding_data[:, col_index] = -1
            
            # Insert padding rows after the last frame of the current gesture
            data = np.insert(data, last_frame_index + 1, padding_data, axis=0)

    # Convert the NumPy array back to a DataFrame
    padded_df = pd.DataFrame(data, columns=columns).drop(columns=num_of_cols)

    # padded_df.to_csv(f"model/LSTM/v2/{time.time()}.csv", index=False)
    # return numpy arrary, number of samples, timesteps, features
    return padded_df.to_numpy(), len(num_of_cols), frame_list[0], len(padded_df.columns.values.tolist())

# %%
def create_lstm(input, output_units):

    activate = "softmax"
    loss_type = "categorical_crossentropy"
    if len(output_units) == 1:
        activate = "sigmoid"
        loss_type = "binary_crossentropy"

    model = Sequential()
    model.add(Masking(mask_value=-1))
    model.add(LSTM(64, return_sequences=True, activation="relu", input_shape=input[1:], kernel_regularizer=L1L2(l1=1e-5, l2=1e-4), bias_regularizer=L2(0.01)))
    model.add(Dropout(0.2))
    model.add(LSTM(24, activation="relu"))
    model.add(Dropout(0.2))
    model.add(Dense(64, activation="relu"))
    model.add(Dense(units=len(np.unique(output_units)), activation=activate,  kernel_regularizer=L1L2(0.0001), bias_regularizer=L2(0.001)))
    
    model.compile(optimizer=Adam(learning_rate=1e-5), loss=loss_type, metrics=['accuracy'])
    return model

# %%
input_dir = "C:\\Users\Gen3r\Documents\\capstone\\ml_model\\data\\data_3"
dataframe = create_dataframe_from_data(input_dir)

# %%
categorical_columns = ["gesture_index"]
landmark_columns = [f"{col}" for col in dataframe.columns if col.startswith(("hx", "hy", "hz", "px", "py", "pz", "lx", "ly", "lz", "rx", "ry", "rz"))]
numerical_columns = ["frame", "frame_rate", "frame_width", "frame_height"] + [f"{col}" for col in dataframe.columns if col.startswith("pose_visibility")]


print(numerical_columns)
# Out:
# ['frame', 'frame_rate', 'frame_width', 'frame_height', 'pose_visibility_0', 'pose_visibility_1', 'pose_visibility_2', 'pose_visibility_3', 'pose_visibility_4', 'pose_visibility_5', 'pose_visibility_6', 'pose_visibility_7', 'pose_visibility_8', 'pose_visibility_9', 'pose_visibility_10', 'pose_visibility_11', 'pose_visibility_12', 'pose_visibility_13', 'pose_visibility_14', 'pose_visibility_15', 'pose_visibility_16', 'pose_visibility_17', 'pose_visibility_18', 'pose_visibility_19', 'pose_visibility_20', 'pose_visibility_21', 'pose_visibility_22', 'pose_visibility_23', 'pose_visibility_24', 'pose_visibility_25', 'pose_visibility_26', 'pose_visibility_27', 'pose_visibility_28', 'pose_visibility_29', 'pose_visibility_30', 'pose_visibility_31', 'pose_visibility_32']

# %%
X_train, y_train, X_test, y_test = split_dataset(dataframe, "gesture", ["frame", "gesture_index"])
print("init:",X_train.shape, X_test.shape, y_train.shape, y_test.shape)

preprocessor = preprocess_pipeline(landmark_columns, numerical_columns, categorical_columns)
X_train_transformed = preprocessor.fit_transform(X_train)
X_test_transformed = preprocessor.transform(X_test)


y_train_reshaped = reshape_y_labels(y_train)
y_test_reshaped = reshape_y_labels(y_test)

y_train_encoded, labels = pd.factorize(y_train_reshaped)
y_test_encoded, _ = pd.factorize(y_test_reshaped)

class_labels = labels

y_train_one_hot = to_categorical(y_train_encoded, num_classes=len(labels))
y_test_one_hot = to_categorical(y_test_encoded, num_classes=len(labels))

X_train_padded, batch_size1, steps_len1, num_features = pad_dataframe(X_train_transformed)
X_test_padded, batch_size3, steps_len3, num_features3 = pad_dataframe(X_test_transformed)

X_train_reshaped = np.reshape(X_train_padded, (batch_size1, steps_len1, num_features))
X_test_reshaped = np.reshape(X_test_padded, (batch_size3, steps_len3, num_features3))

print("before lstm:",X_train_reshaped.shape, X_test_reshaped.shape, y_train_one_hot.shape, y_test_one_hot.shape)
# Out:
# init: (1632, 1667) (408, 1667) (1632, 3) (408, 3)
# before lstm: (68, 24, 1666) (68, 6, 1666) (68, 2) (68, 2)

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)	
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=4, min_lr=1e-10)	
input = (X_train_reshaped.shape[0], X_train_reshaped.shape[1], X_train_reshaped.shape[2])
model = create_lstm(input, labels)
history = model.fit(
    X_train_reshaped, y_train_one_hot, 
    epochs=300, 
    batch_size=batch_size1, 
    validation_split=0.20,
    callbacks=[early_stopping, reduce_lr],
)

test_loss, test_acc = model.evaluate(X_test_reshaped, y_test_one_hot)	
print(f'Test Accuracy: {test_acc} || Test Loss: {test_loss}')
# Out:
# Epoch 1/300
# c:\Users\Gen3r\Documents\capstone\ml_model\lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step - accuracy: 0.6111 - loss: 3.4511 - val_accuracy: 0.0000e+00 - val_loss: 4.1323 - learning_rate: 1.0000e-05
# Epoch 2/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.6111 - loss: 2.8725 - val_accuracy: 0.0000e+00 - val_loss: 3.8151 - learning_rate: 1.0000e-05
# Epoch 3/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.5926 - loss: 2.7964 - val_accuracy: 0.0000e+00 - val_loss: 3.5411 - learning_rate: 1.0000e-05
# Epoch 4/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.6111 - loss: 2.8671 - val_accuracy: 0.0000e+00 - val_loss: 3.2971 - learning_rate: 1.0000e-05
# Epoch 5/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.6111 - loss: 2.5178 - val_accuracy: 0.0000e+00 - val_loss: 3.0954 - learning_rate: 1.0000e-05
# Epoch 6/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.6111 - loss: 2.4701 - val_accuracy: 0.0000e+00 - val_loss: 2.9314 - learning_rate: 1.0000e-05
# Epoch 7/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.5926 - loss: 2.4966 - val_accuracy: 0.0000e+00 - val_loss: 2.8007 - learning_rate: 1.0000e-05
# Epoch 8/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.6111 - loss: 2.3113 - val_accuracy: 0.0000e+00 - val_loss: 2.6985 - learning_rate: 1.0000e-05
# Epoch 9/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.5926 - loss: 2.2453 - val_accuracy: 0.0000e+00 - val_loss: 2.6235 - learning_rate: 1.0000e-05
# Epoch 10/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.6296 - loss: 2.2658 - val_accuracy: 0.0714 - val_loss: 2.5682 - learning_rate: 1.0000e-05
# Epoch 11/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.6296 - loss: 2.1921 - val_accuracy: 0.1429 - val_loss: 2.5274 - learning_rate: 1.0000e-05
# Epoch 12/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.6481 - loss: 2.2601 - val_accuracy: 0.1429 - val_loss: 2.4950 - learning_rate: 1.0000e-05
# Epoch 13/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.6296 - loss: 2.2010 - val_accuracy: 0.1429 - val_loss: 2.4709 - learning_rate: 1.0000e-05
# Epoch 14/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.6481 - loss: 2.1766 - val_accuracy: 0.1429 - val_loss: 2.4536 - learning_rate: 1.0000e-05
# Epoch 15/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.6111 - loss: 2.1998 - val_accuracy: 0.1429 - val_loss: 2.4414 - learning_rate: 1.0000e-05
# Epoch 16/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.6296 - loss: 2.1600 - val_accuracy: 0.1429 - val_loss: 2.4312 - learning_rate: 1.0000e-05
# Epoch 17/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.6111 - loss: 2.1640 - val_accuracy: 0.1429 - val_loss: 2.4230 - learning_rate: 1.0000e-05
# Epoch 18/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.6111 - loss: 2.1303 - val_accuracy: 0.1429 - val_loss: 2.4163 - learning_rate: 1.0000e-05
# Epoch 19/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.6111 - loss: 2.1329 - val_accuracy: 0.1429 - val_loss: 2.4115 - learning_rate: 1.0000e-05
# Epoch 20/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.6667 - loss: 2.1019 - val_accuracy: 0.2143 - val_loss: 2.4070 - learning_rate: 1.0000e-05
# Epoch 21/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.6667 - loss: 2.1179 - val_accuracy: 0.2143 - val_loss: 2.4035 - learning_rate: 1.0000e-05
# Epoch 22/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.6667 - loss: 2.0383 - val_accuracy: 0.2143 - val_loss: 2.3998 - learning_rate: 1.0000e-05
# Epoch 23/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.6667 - loss: 2.0604 - val_accuracy: 0.2857 - val_loss: 2.3959 - learning_rate: 1.0000e-05
# Epoch 24/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.6481 - loss: 2.0746 - val_accuracy: 0.2857 - val_loss: 2.3918 - learning_rate: 1.0000e-05
# Epoch 25/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.6852 - loss: 2.0225 - val_accuracy: 0.2857 - val_loss: 2.3864 - learning_rate: 1.0000e-05
# Epoch 26/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.6667 - loss: 2.0592 - val_accuracy: 0.2857 - val_loss: 2.3800 - learning_rate: 1.0000e-05
# Epoch 27/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.7037 - loss: 2.0479 - val_accuracy: 0.2857 - val_loss: 2.3723 - learning_rate: 1.0000e-05
# Epoch 28/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.7407 - loss: 1.9933 - val_accuracy: 0.2857 - val_loss: 2.3618 - learning_rate: 1.0000e-05
# Epoch 29/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.7222 - loss: 1.9878 - val_accuracy: 0.3571 - val_loss: 2.3495 - learning_rate: 1.0000e-05
# Epoch 30/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.7037 - loss: 2.0077 - val_accuracy: 0.3571 - val_loss: 2.3351 - learning_rate: 1.0000e-05
# Epoch 31/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.7593 - loss: 1.9568 - val_accuracy: 0.3571 - val_loss: 2.3152 - learning_rate: 1.0000e-05
# Epoch 32/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.7222 - loss: 1.9557 - val_accuracy: 0.3571 - val_loss: 2.2900 - learning_rate: 1.0000e-05
# Epoch 33/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.7963 - loss: 1.9516 - val_accuracy: 0.4286 - val_loss: 2.2650 - learning_rate: 1.0000e-05
# Epoch 34/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.7222 - loss: 1.9639 - val_accuracy: 0.4286 - val_loss: 2.2377 - learning_rate: 1.0000e-05
# Epoch 35/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.7407 - loss: 1.9548 - val_accuracy: 0.4286 - val_loss: 2.2075 - learning_rate: 1.0000e-05
# Epoch 36/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.8333 - loss: 1.9502 - val_accuracy: 0.6429 - val_loss: 2.1747 - learning_rate: 1.0000e-05
# Epoch 37/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.8889 - loss: 1.8809 - val_accuracy: 0.7857 - val_loss: 2.1411 - learning_rate: 1.0000e-05
# Epoch 38/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.8519 - loss: 1.9298 - val_accuracy: 0.8571 - val_loss: 2.1104 - learning_rate: 1.0000e-05
# Epoch 39/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.7778 - loss: 1.9283 - val_accuracy: 0.9286 - val_loss: 2.0817 - learning_rate: 1.0000e-05
# Epoch 40/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.9074 - loss: 1.8639 - val_accuracy: 0.9286 - val_loss: 2.0531 - learning_rate: 1.0000e-05
# Epoch 41/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.8889 - loss: 1.8960 - val_accuracy: 0.9286 - val_loss: 2.0238 - learning_rate: 1.0000e-05
# Epoch 42/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.8704 - loss: 1.9053 - val_accuracy: 0.9286 - val_loss: 1.9928 - learning_rate: 1.0000e-05
# Epoch 43/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.8333 - loss: 1.8930 - val_accuracy: 0.9286 - val_loss: 1.9626 - learning_rate: 1.0000e-05
# Epoch 44/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.9074 - loss: 1.8550 - val_accuracy: 0.9286 - val_loss: 1.9397 - learning_rate: 1.0000e-05
# Epoch 45/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.8889 - loss: 1.8349 - val_accuracy: 0.9286 - val_loss: 1.9178 - learning_rate: 1.0000e-05
# Epoch 46/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9259 - loss: 1.8402 - val_accuracy: 0.9286 - val_loss: 1.8965 - learning_rate: 1.0000e-05
# Epoch 47/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.9259 - loss: 1.8347 - val_accuracy: 0.9286 - val_loss: 1.8746 - learning_rate: 1.0000e-05
# Epoch 48/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.9074 - loss: 1.8023 - val_accuracy: 0.9286 - val_loss: 1.8554 - learning_rate: 1.0000e-05
# Epoch 49/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.8704 - loss: 1.8278 - val_accuracy: 0.9286 - val_loss: 1.8370 - learning_rate: 1.0000e-05
# Epoch 50/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.9444 - loss: 1.7735 - val_accuracy: 0.9286 - val_loss: 1.8200 - learning_rate: 1.0000e-05
# Epoch 51/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.8704 - loss: 1.8439 - val_accuracy: 0.9286 - val_loss: 1.8049 - learning_rate: 1.0000e-05
# Epoch 52/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.9259 - loss: 1.8269 - val_accuracy: 0.9286 - val_loss: 1.7916 - learning_rate: 1.0000e-05
# Epoch 53/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.8519 - loss: 1.8574 - val_accuracy: 0.9286 - val_loss: 1.7799 - learning_rate: 1.0000e-05
# Epoch 54/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.9630 - loss: 1.7595 - val_accuracy: 0.9286 - val_loss: 1.7697 - learning_rate: 1.0000e-05
# Epoch 55/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.9630 - loss: 1.7320 - val_accuracy: 0.9286 - val_loss: 1.7600 - learning_rate: 1.0000e-05
# Epoch 56/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.9630 - loss: 1.7390 - val_accuracy: 0.9286 - val_loss: 1.7501 - learning_rate: 1.0000e-05
# Epoch 57/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.9259 - loss: 1.7950 - val_accuracy: 0.9286 - val_loss: 1.7411 - learning_rate: 1.0000e-05
# Epoch 58/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.9444 - loss: 1.8196 - val_accuracy: 0.9286 - val_loss: 1.7338 - learning_rate: 1.0000e-05
# Epoch 59/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.9630 - loss: 1.7063 - val_accuracy: 0.9286 - val_loss: 1.7255 - learning_rate: 1.0000e-05
# Epoch 60/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9074 - loss: 1.7585 - val_accuracy: 0.9286 - val_loss: 1.7186 - learning_rate: 1.0000e-05
# Epoch 61/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.9630 - loss: 1.7475 - val_accuracy: 0.9286 - val_loss: 1.7131 - learning_rate: 1.0000e-05
# Epoch 62/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.9815 - loss: 1.7815 - val_accuracy: 0.9286 - val_loss: 1.7093 - learning_rate: 1.0000e-05
# Epoch 63/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.9444 - loss: 1.7648 - val_accuracy: 0.9286 - val_loss: 1.7065 - learning_rate: 1.0000e-05
# Epoch 64/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.9259 - loss: 1.7541 - val_accuracy: 0.9286 - val_loss: 1.7033 - learning_rate: 1.0000e-05
# Epoch 65/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9815 - loss: 1.7083 - val_accuracy: 0.9286 - val_loss: 1.7006 - learning_rate: 1.0000e-05
# Epoch 66/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.9815 - loss: 1.7120 - val_accuracy: 0.9286 - val_loss: 1.6986 - learning_rate: 1.0000e-05
# Epoch 67/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9630 - loss: 1.6900 - val_accuracy: 0.9286 - val_loss: 1.6961 - learning_rate: 1.0000e-05
# Epoch 68/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.9444 - loss: 1.7431 - val_accuracy: 0.9286 - val_loss: 1.6938 - learning_rate: 1.0000e-05
# Epoch 69/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.9815 - loss: 1.6980 - val_accuracy: 0.9286 - val_loss: 1.6920 - learning_rate: 1.0000e-05
# Epoch 70/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9259 - loss: 1.6985 - val_accuracy: 0.9286 - val_loss: 1.6903 - learning_rate: 1.0000e-05
# Epoch 71/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.9444 - loss: 1.7435 - val_accuracy: 0.9286 - val_loss: 1.6892 - learning_rate: 1.0000e-05
# Epoch 72/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.9630 - loss: 1.6562 - val_accuracy: 0.9286 - val_loss: 1.6871 - learning_rate: 1.0000e-05
# Epoch 73/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.9630 - loss: 1.7324 - val_accuracy: 0.9286 - val_loss: 1.6850 - learning_rate: 1.0000e-05
# Epoch 74/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.9630 - loss: 1.7028 - val_accuracy: 0.9286 - val_loss: 1.6832 - learning_rate: 1.0000e-05
# Epoch 75/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9630 - loss: 1.7084 - val_accuracy: 0.9286 - val_loss: 1.6816 - learning_rate: 1.0000e-05
# Epoch 76/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.9630 - loss: 1.7134 - val_accuracy: 0.9286 - val_loss: 1.6804 - learning_rate: 1.0000e-05
# Epoch 77/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 1.0000 - loss: 1.6501 - val_accuracy: 0.9286 - val_loss: 1.6786 - learning_rate: 1.0000e-05
# Epoch 78/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.9630 - loss: 1.6818 - val_accuracy: 0.9286 - val_loss: 1.6768 - learning_rate: 1.0000e-05
# Epoch 79/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.9630 - loss: 1.6631 - val_accuracy: 0.9286 - val_loss: 1.6743 - learning_rate: 1.0000e-05
# Epoch 80/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.9630 - loss: 1.7124 - val_accuracy: 0.9286 - val_loss: 1.6724 - learning_rate: 1.0000e-05
# Epoch 81/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.9444 - loss: 1.7527 - val_accuracy: 0.9286 - val_loss: 1.6718 - learning_rate: 1.0000e-05
# Epoch 82/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.9630 - loss: 1.7070 - val_accuracy: 0.9286 - val_loss: 1.6714 - learning_rate: 1.0000e-05
# Epoch 83/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9630 - loss: 1.6784 - val_accuracy: 0.9286 - val_loss: 1.6720 - learning_rate: 1.0000e-05
# Epoch 84/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.9630 - loss: 1.7129 - val_accuracy: 0.9286 - val_loss: 1.6720 - learning_rate: 1.0000e-05
# Epoch 85/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9444 - loss: 1.7344 - val_accuracy: 0.9286 - val_loss: 1.6723 - learning_rate: 1.0000e-05
# Epoch 86/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9444 - loss: 1.7154 - val_accuracy: 0.9286 - val_loss: 1.6729 - learning_rate: 1.0000e-05
# Epoch 87/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.9444 - loss: 1.7027 - val_accuracy: 0.9286 - val_loss: 1.6731 - learning_rate: 5.0000e-06
# Epoch 88/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.9630 - loss: 1.7042 - val_accuracy: 0.9286 - val_loss: 1.6737 - learning_rate: 5.0000e-06
# Epoch 89/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.9630 - loss: 1.6674 - val_accuracy: 0.9286 - val_loss: 1.6738 - learning_rate: 5.0000e-06
# Epoch 90/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.9630 - loss: 1.6952 - val_accuracy: 0.9286 - val_loss: 1.6742 - learning_rate: 5.0000e-06
# Epoch 91/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.9815 - loss: 1.6456 - val_accuracy: 0.9286 - val_loss: 1.6744 - learning_rate: 2.5000e-06
# Epoch 92/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.9444 - loss: 1.7024 - val_accuracy: 0.9286 - val_loss: 1.6747 - learning_rate: 2.5000e-06
# Epoch 93/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.9630 - loss: 1.6445 - val_accuracy: 0.9286 - val_loss: 1.6748 - learning_rate: 2.5000e-06
# Epoch 94/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.9630 - loss: 1.7268 - val_accuracy: 0.9286 - val_loss: 1.6748 - learning_rate: 2.5000e-06
# Epoch 95/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 0.9630 - loss: 1.7074 - val_accuracy: 0.9286 - val_loss: 1.6748 - learning_rate: 1.2500e-06
# Epoch 96/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.9444 - loss: 1.7001 - val_accuracy: 0.9286 - val_loss: 1.6749 - learning_rate: 1.2500e-06
# Epoch 97/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9259 - loss: 1.7012 - val_accuracy: 0.9286 - val_loss: 1.6748 - learning_rate: 1.2500e-06
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8840 - loss: 2.0872
# Test Accuracy: 0.8382353186607361 || Test Loss: 2.123002290725708

# %%
y_pred = model.predict(X_test_reshaped)
y_test_labels = np.argmax(y_test_one_hot, axis=1)
y_pred_labels = np.argmax(y_pred, axis=1)
labels = np.unique(np.concatenate((y_test_labels, y_pred_labels)))
cm = confusion_matrix(y_test_labels, y_pred_labels, labels=labels)
print("labels:", class_labels)


# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.ion()
plt.show()

# Extracting the history
train_loss = history.history['loss']
val_loss = history.history['val_loss']
train_acc = history.history['accuracy']
val_acc= history.history['val_accuracy']
epochs = range(1, len(train_loss) + 1)
epochs = range(len(train_loss))  # Assuming loss recorded for each epoch

# Plotting
plt.plot(epochs, train_loss, label='Train Loss')
plt.plot(epochs, val_loss, label='Validation Loss')

plt.title('Training and Test Loss (LSTM Keras Model)')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()


plt.plot(epochs, train_acc, label='Accuracy')
plt.plot(epochs, val_acc, label='Val Accuracy')
plt.title('Accuracy(LSTM Keras Model)')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# labels: Index(['EAT', 'DRINK'], dtype='object')

# %%
model.save(filepath="modelv2.keras")
pd.DataFrame.to_csv(class_labels, "class_labels.csv", index=False)
joblib.dump(preprocessor, "preprocess.pkl")
# print(model.get_weights())
# Out:
# ['preprocess.pkl']

# %%
X_new_sample = pd.read_csv("eat2.csv") # 87
X_new_sampl2 = pd.read_csv("drink2.csv") # 27


X_new_sample = np.reshape(X_new_sample, ( 1, X_new_sample.shape[0], X_new_sample.shape[1]))

ny_pred = model.predict(X_new_sample)
npredicted_labels = [class_labels[np.argmax(pred)] for pred in ny_pred]
print(npredicted_labels)

# confusion matrix to see if model is making errors
ground_truth_labels = ['EAT'] * len(npredicted_labels) # has to do with how many labels are there in a run

# Generate confusion matrix

cm = confusion_matrix(ground_truth_labels, npredicted_labels, labels=class_labels)

# Plot confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# ['EAT', 'EAT', 'EAT', 'EAT', 'EAT', 'EAT', 'EAT', 'EAT', 'EAT', 'EAT', 'EAT', 'EAT', 'EAT', 'EAT', 'EAT', 'EAT', 'EAT', 'EAT', 'EAT', 'EAT', 'EAT', 'EAT', 'EAT', 'EAT', 'EAT', 'EAT', 'EAT', 'EAT', 'EAT', 'EAT', 'EAT', 'EAT', 'EAT', 'EAT', 'EAT', 'DRINK', 'EAT', 'DRINK', 'EAT', 'EAT', 'DRINK', 'DRINK', 'EAT', 'EAT', 'EAT', 'DRINK', 'DRINK', 'DRINK', 'DRINK', 'DRINK', 'DRINK', 'DRINK', 'DRINK', 'DRINK', 'DRINK', 'DRINK', 'DRINK', 'DRINK', 'DRINK', 'DRINK', 'DRINK', 'DRINK', 'DRINK', 'EAT', 'EAT', 'EAT', 'DRINK', 'DRINK']
